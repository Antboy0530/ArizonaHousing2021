# %%
import pandas as pd 
import numpy as np
import re
import matplotlib.pyplot as plt
import warnings #use this to get rid of warnings
warnings.filterwarnings('ignore')

# %%
var = pd.read_csv("AzhouseData.csv")
var
# Out:
#         Price                     address      Local_area  zipcode   latitude  \
# 0    $229,900      11444 N 28th Dr APT 14         Phoenix    85029  33.591906
# 1    $294,900  107 W Camino Rancho Lucido       Sahuarita    85629  31.980608
# 2    $683,100        3320 E Briarwood Ter         Phoenix    85048  33.296776
# 3    $260,000        2401 N 70th St APT H      Scottsdale    85257  33.474553
# 4    $290,900          3781 E Sierrita Rd  San Tan Valley    85143  33.133083
# ..        ...                         ...             ...      ...        ...
# 175  $315,000               1018 E Ash St      Cottonwood    86326  34.737676
# 176  $494,900            7537 W Eugie Ave          Peoria    85381  33.607946
# 177  $375,000        25802 S Brentwood Dr       Sun Lakes    85248  33.212848
# 178  $395,000            844 E Rosebud Dr  San Tan Valley    85143  33.168841
# 179  $389,900           67 Wagon Wheel Ln         Sonoita    85637  31.658037
#
# ...

# %%
var.describe()
# Out:
#             zipcode    latitude   longitude
# count    180.000000  180.000000  180.000000
# mean   85497.266667   33.390425 -111.724251
# std      397.950751    0.860921    0.925400
# min    85006.000000   31.436752 -114.637577
# 25%    85207.000000   33.060699 -112.194849
# 50%    85348.000000   33.438675 -111.867214
# 75%    85737.000000   33.719949 -111.095824
# max    86409.000000   35.267850 -109.050170

# %%
var.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Price       180 non-null    object
#  1   address     180 non-null    object
#  2   Local_area  180 non-null    object
#  3   zipcode     180 non-null    int64
#  4   latitude    180 non-null    float64
#  5   longitude   180 non-null    float64
#  6   beds        180 non-null    object
#  7   baths       180 non-null    object
#  8   sqft        177 non-null    object
#  9   url         180 non-null    object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 14.2+ KB

# %% [markdown]
# # Cleaning Data

# %%
var[var.isna().any(axis=1)]
# Out:
#         Price                 address Local_area  zipcode   latitude  \
# 121    $7,947     2007 Snake Ranch Rd     Concho    85924  34.458120
# 125   $69,500  2101 W Irvine Rd LOT 0    Phoenix    85086  33.834878
# 147  $143,000   5576 Big Game Trl #18  Flagstaff    86001  35.059260
#
#       longitude            beds                  baths sqft  \
# 121 -109.525498    10 acres lot  - Lot / Land for sale  NaN
# 125 -112.105191  2.35 acres lot  - Lot / Land for sale  NaN
# 147 -111.558986  1.37 acres lot  - Lot / Land for sale  NaN
#
#                                                    url
# 121  https://www.zillow.com/homedetails/2007-Snake-...
# 125  https://www.zillow.com/homedetails/2101-W-Irvi...
# 147  https://www.zillow.com/homedetails/5576-Big-Ga...

# %%
# keep only the rows that are not NA under sqft
var2 = var[var['sqft'].notna()]

# %%
var2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 177 entries, 0 to 179
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Price       177 non-null    object
#  1   address     177 non-null    object
#  2   Local_area  177 non-null    object
#  3   zipcode     177 non-null    int64
#  4   latitude    177 non-null    float64
#  5   longitude   177 non-null    float64
#  6   beds        177 non-null    object
#  7   baths       177 non-null    object
#  8   sqft        177 non-null    object
#  9   url         177 non-null    object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 15.2+ KB

# %% [markdown]
# ## clean labels

# %%
var2.loc[:,'beds'] = [x.strip('bds') for x in var2.beds] #locate all rows under beds and strip 'beds'

# %%
var2.loc[:,'baths'] = [x.strip('baths') for x in var2.baths]

# %%
var2.loc[:,'Price'] = [x.strip('$') for x in var2.Price]

# %%
var2
# Out:
#        Price                     address      Local_area  zipcode   latitude  \
# 0    229,900      11444 N 28th Dr APT 14         Phoenix    85029  33.591906
# 1    294,900  107 W Camino Rancho Lucido       Sahuarita    85629  31.980608
# 2    683,100        3320 E Briarwood Ter         Phoenix    85048  33.296776
# 3    260,000        2401 N 70th St APT H      Scottsdale    85257  33.474553
# 4    290,900          3781 E Sierrita Rd  San Tan Valley    85143  33.133083
# ..       ...                         ...             ...      ...        ...
# 175  315,000               1018 E Ash St      Cottonwood    86326  34.737676
# 176  494,900            7537 W Eugie Ave          Peoria    85381  33.607946
# 177  375,000        25802 S Brentwood Dr       Sun Lakes    85248  33.212848
# 178  395,000            844 E Rosebud Dr  San Tan Valley    85143  33.168841
# 179  389,900           67 Wagon Wheel Ln         Sonoita    85637  31.658037
#
#       longitude beds baths   sqft  \
# ...

# %%
var2['beds'] = var2['beds'].apply(pd.to_numeric)

# %%
var2['baths'] = var2['baths'].apply(pd.to_numeric)

# %%
var2['Price'] = var2['Price'].apply(lambda x: x.replace(",", ""))

# %%
var2['sqft'] = var2['sqft'].apply(lambda x: x.replace(",", ""))

# %%
var2
# Out:
#       Price                     address      Local_area  zipcode   latitude  \
# 0    229900      11444 N 28th Dr APT 14         Phoenix    85029  33.591906
# 1    294900  107 W Camino Rancho Lucido       Sahuarita    85629  31.980608
# 2    683100        3320 E Briarwood Ter         Phoenix    85048  33.296776
# 3    260000        2401 N 70th St APT H      Scottsdale    85257  33.474553
# 4    290900          3781 E Sierrita Rd  San Tan Valley    85143  33.133083
# ..      ...                         ...             ...      ...        ...
# 175  315000               1018 E Ash St      Cottonwood    86326  34.737676
# 176  494900            7537 W Eugie Ave          Peoria    85381  33.607946
# 177  375000        25802 S Brentwood Dr       Sun Lakes    85248  33.212848
# 178  395000            844 E Rosebud Dr  San Tan Valley    85143  33.168841
# 179  389900           67 Wagon Wheel Ln         Sonoita    85637  31.658037
#
#       longitude  beds  baths  sqft  \
# ...

# %%
var2.iloc[25, 0] = 221000

# %%
var2.iloc[146, 0] = 345990

# %%
var2['Price'] = var2['Price'].apply(pd.to_numeric)

# %%
var2['sqft'] = var2['sqft'].apply(pd.to_numeric)

# %%
var2.dtypes
# Out:
# Price           int64
# address        object
# Local_area     object
# zipcode         int64
# latitude      float64
# longitude     float64
# beds            int64
# baths           int64
# sqft            int64
# url            object
# dtype: object

# %%
var2 = var2[['Price','address','Local_area', 'zipcode', 'beds', 'baths', 'sqft', 'url']]
var2.to_csv('Zillowhouses.csv',index=False)
